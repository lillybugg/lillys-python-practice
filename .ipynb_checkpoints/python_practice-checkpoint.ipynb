# %% [markdown]
# # Git & JupyterLab Practice
#
# This notebook is for learning how to:
#
# - Connect a GitHub repository to JupyterLab.
# - Use Git from the Arch Linux terminal.
# - Practice the basic Git workflow (`git add`, `git commit`, `git push`, `git pull`).
# - Learn common Git and GitHub vocabulary.
#
# This notebook is intended for experimentation and personal notes rather than a specific coding project.
